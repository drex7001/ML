# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OneHotEncoder, LabelEncoder






X_train
# Out:
#    Age  Gender A/L Stream Career Aspirations Personal Interests Location  \
# 7   22  Female       Arts             Writer           Language   Jaffna
# 2   18    Male   Commerce        Businessman          Economics    Galle
# 4   21    Male        Bio             Doctor            Biology  Colombo
# 3   20  Female       Arts             Artist         Literature   Jaffna
# 6   18    Male   Commerce         Accountant         Accounting    Galle
#
#   Financial Resources Family Background     Extracurricular Activities
# 7          Low-income  First-generation       Debate team, Poetry club
# 2         High-income   Business family     Cricket team, Volunteering
# 4        Middle-class  Educated parents         Basketball team, Music
# 3          Low-income  Educated parents      Theater club, Poetry club
# 6         High-income   Business family  Basketball team, Volunteering

# %%
# Load the dataset
df = pd.read_csv("sample_dataset.csv")

# %%
# Split the dataset into features (independent variables) and label (dependent variable)
# X = df.drop(columns=['Degree Program'])
# y = df['Degree Program']

# %%
# One-hot encode the categorical variables
# encoder = OneHotEncoder()
# X_encoded = pd.DataFrame(encoder.fit_transform(X[['Gender', 'A/L Stream', 'Location']]).toarray(), columns=encoder.get_feature_names(['Gender', 'A/L Stream', 'Location']))
# X = X.drop(columns=['Gender', 'A/L Stream', 'Location'])
# X = pd.concat([X, X_encoded], axis=1)

# # Encode the 'Degree Program' column to numeric format
# label_encoder = LabelEncoder()
# y = label_encoder.fit_transform(y)

# %%
cols = ['Age','Gender','A/L Stream','Career Aspirations','Personal Interests','Location','Financial Resources','Family Background','Extracurricular Activities','Degree Program']
df[cols] = df[cols].apply(LabelEncoder().fit_transform)
df.head()
# Out:
#    Age  Gender  A/L Stream  Career Aspirations  Personal Interests  Location  \
# 0    1       0           3                   3                   4         0
# 1    4       1           1                   4                   2         3
# 2    0       1           2                   2                   3         1
# 3    2       0           0                   1                   6         2
# 4    3       1           1                   3                   1         0
#
#    Financial Resources  Family Background  Extracurricular Activities  \
# 0                    2                  1                           4
# 1                    1                  2                           2
# 2                    0                  0                           3
# 3                    1                  1                           7
# 4                    2                  1                           0
#
#    Degree Program
# 0               6
# 1               2
# 2               1
# 3               5
# 4               6

# %%
x = df[['Age','Gender','A/L Stream','Career Aspirations','Personal Interests','Location','Financial Resources','Family Background','Extracurricular Activities']].values


y = df['Degree Program'].values

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#    Age  Gender A/L Stream Career Aspirations Personal Interests Location  \
# 7   22  Female       Arts             Writer           Language   Jaffna
# 2   18    Male   Commerce        Businessman          Economics    Galle
# 4   21    Male        Bio             Doctor            Biology  Colombo
# 3   20  Female       Arts             Artist         Literature   Jaffna
# 6   18    Male   Commerce         Accountant         Accounting    Galle
#
#   Financial Resources Family Background     Extracurricular Activities
# 7          Low-income  First-generation       Debate team, Poetry club
# 2         High-income   Business family     Cricket team, Volunteering
# 4        Middle-class  Educated parents         Basketball team, Music
# 3          Low-income  Educated parents      Theater club, Poetry club
# 6         High-income   Business family  Basketball team, Volunteering

# %%
# Create a k-nearest neighbors classifier with k=3
knn = KNeighborsClassifier(n_neighbors=3)

# Fit the classifier to the training data
knn.fit(X_train, y_train)

# Predict the labels for the testing data
y_pred = knn.predict(X_test)

# Calculate the accuracy of the classifier on the testing data
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24392/1244588484.py in <module>
#       3
#       4 # Fit the classifier to the training data
# ----> 5 knn.fit(X_train, y_train)
#       6
#       7 # Predict the labels for the testing data
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in fit(self, X, y)
#     177             The fitted k-nearest neighbors classifier.
#     178         """
# --> 179         return self._fit(X, y)
#     180
#     181     def predict(self, X):
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     361         if self._get_tags()["requires_y"]:
#     362             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 363                 X, y = self._validate_data(X, y, accept_sparse="csr",
#     364                                            multi_output=True)
#     365
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     869         raise ValueError("y cannot be None")
#     870
# --> 871     X = check_array(X, accept_sparse=accept_sparse,
#     872                     accept_large_sparse=accept_large_sparse,
#     873                     dtype=dtype, order=order, copy=copy,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'Female'
