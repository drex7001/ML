# %%
import pandas as pd
import random

# Define your arrays for different columns
programs = data = [
    "Bachelor of Technology (BTech) Honours in Agriculture and Plantation Engineering",
    "Bachelor of Industrial Studies Honours - Agriculture",
    "Bachelor of Software Engineering Honours",
    "Bachelor of Technology - Electronic and Communication Engineering",
    "Bachelor of Technology - Mechanical Engineering",
    "Bachelor of Technology - Mechatronics Engineering",
    "Bachelor of Technology - Electrical Engineering",
    "Bachelor of Technology - Computer Engineering",
    "Bachelor of Technology - Civil Engineering",
    "Bachelor of Technology Honours in Engineering – Textile & Clothing",
    "Bachelor of Industrial Studies Honours – Textile Manufacture Specialization",
    "Bachelor of Industrial Studies Honours – Fashion Design and Product Development",
    "Bachelor of Industrial Studies Honours – Apparel Production and Management"
]
genders = ["Male", "Female"]
civil_states = ["Single", "Married"]
districts = districts = [
    "Colombo","Colombo","Colombo","Colombo",
    "Kandy","Kandy","Kurunegala",
    "Gampaha","Colombo","Gampaha",
    "Kalutara","Gampaha","Kurunegala",
    "Matale","Kandy",
    "Nuwara Eliya","Colombo",
    "Kegalle","Gampaha",
    "Ratnapura","Kandy",
    "Trincomalee",
    "Batticaloa","Colombo","Kandy",
    "Ampara","Gampaha",
    "Badulla","Kandy",
    "Monaragala",
    "Hambantota","Colombo",
    "Matara","Gampaha","Kandy",
    "Galle","Kandy",
    "Kurunegala","Colombo","Kurunegala",
    "Puttalam","Gampaha",
    "Anuradhapura","Colombo","Kurunegala",
    "Polonnaruwa","Kurunegala",
    "Mannar","Gampaha",
    "Vavuniya","Colombo",
    "Mullaitivu","Gampaha","Kurunegala",
    "Kilinochchi","Colombo",
    "Jaffna","Kurunegala",
    "Mullaitivu""Colombo",
]
work_experiences = ["No experience", "0-1 years", "1-2 years","2-3 years","More than 3 years"]
streams = ["Biology","Biology","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Biology","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Biology","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Biology","Biology","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Biology","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Biology","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Mathematics","Mathematics","Commerce" 
"Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Commerce" 
"Mathematics","Mathematics","Mathematics","Mathematics","Commerce" 
"Arts","Mathematics","Biology","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Mathematics","Mathematics","Commerce" 
"Arts","Mathematics","Mathematics","Mathematics","Mathematics","Arts","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics","Commerce" 
"Arts","Mathematics","Mathematics","Mathematics","Mathematics","Mathematics"]
age_range = (19, 26)

# Define the size of the dataset
num_rows = 1500

# Generate fake data
data = pd.DataFrame(columns=["program", "Age", "Gender", "Civil State", "District", "Work Experience", "OL-A", "OL-B", "OL-C", "OL-S",
                             "AL stream", "AL-A", "AL-B", "AL-C", "AL-S"])

for _ in range(num_rows):
    program = random.choice(programs)
    age = random.randint(age_range[0], age_range[1])
    gender = random.choice(genders)
    civil_state = random.choice(civil_states)
    district = random.choice(districts)
    work_experience = random.choice(work_experiences)
    
    ol_a = random.randint(0, 9)
    ol_b = random.randint(0, 9 - ol_a)
    ol_c = random.randint(0, 9 - ol_a - ol_b)
    ol_s = 9 - ol_a - ol_b - ol_c
    
    al_stream = random.choice(streams)
    al_a = random.randint(0, 3)
    al_b = random.randint(0, 3 - al_a)
    al_c = random.randint(0, 3 - al_a - al_b)
    al_s = 3 - al_a - al_b - al_c
    
    row = {
        "program": program,
        "Age": age,
        "Gender": gender,
        "Civil State": civil_state,
        "District": district,
        "Work Experience": work_experience,
        "OL-A": ol_a,
        "OL-B": ol_b,
        "OL-C": ol_c,
        "OL-S": ol_s,
        "AL stream": al_stream,
        "AL-A": al_a,
        "AL-B": al_b,
        "AL-C": al_c,
        "AL-S": al_s
    }
    
    data = data.append(row, ignore_index=True)

# Print the generated dataset
print(data.head())
data.to_csv("fake_dataset.csv", index=False)
# Out:
#                                              program Age  Gender Civil State  \
# 0  Bachelor of Technology - Electronic and Commun...  23    Male     Married
# 1  Bachelor of Industrial Studies Honours – Appar...  24    Male      Single
# 2  Bachelor of Industrial Studies Honours - Agric...  19    Male     Married
# 3  Bachelor of Technology - Mechatronics Engineering  19  Female      Single
# 4  Bachelor of Industrial Studies Honours – Appar...  22  Female     Married
#
#      District    Work Experience OL-A OL-B OL-C OL-S    AL stream AL-A AL-B  \
# 0     Colombo          2-3 years    1    7    1    0  Mathematics    3    0
# 1    Vavuniya          0-1 years    5    1    0    3  Mathematics    3    0
# 2       Kandy  More than 3 years    8    0    1    0  Mathematics    3    0
# 3     Gampaha          2-3 years    1    1    2    5  Mathematics    2    1
# 4  Hambantota      No experience    7    2    0    0  Mathematics    0    2
#
#   AL-C AL-S
# 0    0    0
# 1    0    0
# ...
